# %% [markdown]
# ## PREDICTING SEPSIS DISEASE: Using Machine Learning API/Fast API

# %% [markdown]
# ## **1. Business Understanding**
# In the context of healthcare analytics, our dataset focuses on patients within an Intensive Care Unit (ICU), with a specific emphasis on factors associated with the development of sepsis. Sepsis is a critical medical condition characterized by a systemic inflammatory response to infection, potentially leading to organ dysfunction and failure, and it is regarded as a medical emergency.
#
#   #### **Dataset Overview:**
# The dataset comprises essential medical attributes, including:
# - **ID (Patient ID)**: Unique identifier assigned to each patient.
# - **PRG (Plasma Glucose)**: Represents the level of glucose in the patient's plasma.
# - **PL (Blood Work Result-1)**: First blood work result, measured in mu U/ml.Procalcitonin is a biomarker that can be elevated in response to bacterial infections, including sepsis. The unit "mu U/ml" suggests the measurement is in micrograms per milliliter.
# - **PR (Blood Pressure)**: Represents the patient's blood pressure in mm Hg.
# - **SK (Blood Work Result-2)**: Second blood work result, measured in mm. White blood cell count (WBC) is a common test used to assess the body's immune response.
# - **TS (Blood Work Result-3)**: Third blood work result, measured in mu U/ml. checking the lactate Levels.
# - **M11 (Body Mass Index)**: Calculated body mass index (BMI) using weight in kg and height in meters.
# - **BD2 (Blood Work Result-4)**: Fourth blood work result, measured in mu U/ml. CRP is an inflammatory marker that can be elevated in response to various conditions, including infections like sepsis
# - **Age**: Represents the age of the patient in years.
# - **Insurance**: Indicates whether the patient holds a valid insurance card.
# - **Sepsis (Target)**: The target variable indicating whether a patient in the ICU will develop sepsis (Positive) or not (Negative).
#
# ### **Business Objective:**
# Our primary goal is to glean actionable insights from this data to enhance our understanding of sepsis risk factors. By leveraging advanced analytics and potentially developing predictive models, we aim to facilitate early detection and intervention strategies. This, in turn, could significantly improve patient outcomes in the ICU setting, aligning with the broader healthcare objective of providing timely and targeted care to those at risk of sepsis.
#
# Source:https://www.kaggle.com/datasets/chaunguynnghunh/sepsis/?select=Paitients_Files_Train.csv

# %% [markdown]
# ### Formulating Hypothesis and Business Questions
#
# #### **Hypothesis**
# - **Null Hypothesis (H0)**: Age does not significantly impact the susceptibility to sepsis in ICU patients.
# - **Alternative Hypothesis (H1)**: Older patients are more susceptible to sepsis in the ICU compared to younger individuals.
#
# #### **Business Questions**:
# **Univariate Analysis**
#
# 1. How many patients tested positive  vs Negative to Sepsis
#
# **Bivariate Analysis:**
#
# 2. Is there a significant correlation between patients' age and the plasma glucose levels (PRG) with patients that tested positive to Sepssis?
#
# 3. What is the association between blood pressure (PR) and the risk of developing sepsis in ICU patients? Are there specific blood pressure ranges that are more commonly observed in patients who develop sepsis?
#
# 4. Does the body mass index (M11) of ICU patients show any significant correlation with specific blood work results, such as plasma glucose (PRG) or blood work result-4 (BD2)?
#
# 5.  How does the distribution of patients' age vary across different insurance groups?
#
# **Multivariate Analysis**
#
# 6. How do age, plasma glucose levels (PRG), and blood pressure (PR) collectively contribute to the prediction of sepsis outcomes in ICU patients?

# %% [markdown]
# ## **2. Data Understanding**

# %% [markdown]
# ##### I. Importation

# %%
#Importing data exploration/Visualization libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#Data Preposessing libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler,FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from collections import Counter

#models libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

#model evaluation Libraries
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

#Model Improvement
from sklearn.model_selection import GridSearchCV
from scipy.stats import randint

import joblib

# %% [markdown]
# ##### **II. Load Datasets**

# %%
# Loading Train and Test Data
train =pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
#Preview of train data
train.head(3)
# Out:
#           ID  PRG   PL  PR  SK  TS   M11    BD2  Age  Insurance   Sepssis
# 0  ICU200010    6  148  72  35   0  33.6  0.627   50          0  Positive
# 1  ICU200011    1   85  66  29   0  26.6  0.351   31          0  Negative
# 2  ICU200012    8  183  64   0   0  23.3  0.672   32          1  Positive

# %%
#Preview of test data
test.head(3)
# Out:
#           ID  PRG   PL  PR  SK   TS   M11    BD2  Age  Insurance
# 0  ICU200609    1  109  38  18  120  23.1  0.407   26          1
# 1  ICU200610    1  108  88  19    0  27.1  0.400   24          1
# 2  ICU200611    6   96   0   0    0  23.7  0.190   28          1

# %% [markdown]
# ##### **III. EDA Analysis**

# %%
#checking for missing values in both train and test data
train.isnull().sum(), test.isnull().sum()
# Out:
# (ID           0
#  PRG          0
#  PL           0
#  PR           0
#  SK           0
#  TS           0
#  M11          0
#  BD2          0
#  Age          0
#  Insurance    0
#  Sepssis      0
#  dtype: int64,
#  ID           0
#  PRG          0
#  PL           0
#  PR           0
#  SK           0
#  TS           0
#  M11          0
#  BD2          0
#  Age          0
#  Insurance    0
#  dtype: int64)

# %%
#checking for duplicates
train.duplicated().sum(),test.duplicated().sum()
# Out:
# (0, 0)

# %%
#Statistical analysis
train.describe().T
# Out:
#            count        mean         std     min     25%      50%      75%  \
# PRG        599.0    3.824708    3.362839   0.000   1.000    3.000    6.000
# PL         599.0  120.153589   32.682364   0.000  99.000  116.000  140.000
# PR         599.0   68.732888   19.335675   0.000  64.000   70.000   80.000
# SK         599.0   20.562604   16.017622   0.000   0.000   23.000   32.000
# TS         599.0   79.460768  116.576176   0.000   0.000   36.000  123.500
# M11        599.0   31.920033    8.008227   0.000  27.100   32.000   36.550
# BD2        599.0    0.481187    0.337552   0.078   0.248    0.383    0.647
# Age        599.0   33.290484   11.828446  21.000  24.000   29.000   40.000
# Insurance  599.0    0.686144    0.464447   0.000   0.000    1.000    1.000
#
#               max
# PRG         17.00
# PL         198.00
# PR         122.00
# SK          99.00
# TS         846.00
# M11         67.10
# BD2          2.42
# Age         81.00
# Insurance    1.00

# %% [markdown]
# The TS attribute has highest max units compared to the rest of the attributes. There is a possibility of outliers which will be detected on EDA visualization

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         599 non-null    object
#  1   PRG        599 non-null    int64
#  2   PL         599 non-null    int64
#  3   PR         599 non-null    int64
#  4   SK         599 non-null    int64
#  5   TS         599 non-null    int64
#  6   M11        599 non-null    float64
#  7   BD2        599 non-null    float64
#  8   Age        599 non-null    int64
#  9   Insurance  599 non-null    int64
#  10  Sepssis    599 non-null    object
# dtypes: float64(2), int64(7), object(2)
# memory usage: 51.6+ KB

# %% [markdown]
# 2 of attributes are objects i.e ID and Sepssis and the rest others are numerical.

# %%
#visualizing the distribution of the numerical attributes
train.hist(bins = 20,figsize=(15, 10), layout=(3, 3), grid= False)
# Out:
# array([[<Axes: title={'center': 'PRG'}>, <Axes: title={'center': 'PL'}>,
#         <Axes: title={'center': 'PR'}>],
#        [<Axes: title={'center': 'SK'}>, <Axes: title={'center': 'TS'}>,
#         <Axes: title={'center': 'M11'}>],
#        [<Axes: title={'center': 'BD2'}>, <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Insurance'}>]], dtype=object)

# %% [markdown]
# - Most of the attributes are Skewed to the Right (Positively Skewed): The right tail is longer or fatter than the left, indicating a concentration of data on the left side. These are PRG,SK,BD2,Age and TS.
# - They assume a bell curve but not a perfect bell curved distribution.

# %%
#using the box plot to visualize for presence of outliers
sns.boxplot(data = train, orient= 'h')
plt.figure(figsize=(10,12))
plt.show()

# %% [markdown]
# There is presence of outliers in the dataset. TS attribute has far most outliers compared to other attributes. The attributes however are on different scales.

# %%
#Using a heatmap to show correlation of the attributes
#Filtering only numerical attributes
numeric_train = train.select_dtypes(include='number')
corr = numeric_train.corr()
heatmap =sns.heatmap(corr,annot = True, cmap = 'coolwarm',linewidths=.5)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize': 18}, pad=12)
plt.show()

# %% [markdown]
# There is weak correlation among the attributes. However the age and plasma glucose(PRG) has strong correlation of 0.53.

# %% [markdown]
# ##### **IV. Answering The Business Questions**

# %% [markdown]
# Univariate Analysis
#
# **1. How many patients tested positive  vs Negative to Sepsis**

# %%
# Count the number of positive and negative cases
sepsis_counts = train['Sepssis'].value_counts()

# Create a pie chart
labels = ['Negative', 'Positive']
colors = ['skyblue', 'lightcoral']
explode = (0, 0.1)  # Explode the 'Positive' slice for emphasis

plt.figure(figsize=(8, 8))
plt.pie(sepsis_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=explode)
plt.title('Distribution of Sepssis Test Results')
plt.show()

# Print the counts
print("Number of patients tested Negative for Sepsis:", sepsis_counts['Negative'])
print("Number of patients tested Positive for Sepsis:", sepsis_counts['Positive'])
# Out:
# Number of patients tested Negative for Sepsis: 391
# Number of patients tested Positive for Sepsis: 208

# %% [markdown]
# **Bivariate Analysis:**
#
# **2. Is there a significant correlation between patients' age and the plasma glucose levels (PRG) with patients that tested positive to Sepssis?**

# %%
# Filter data for patients with positive sepsis test results
sepsis_positive_data = train[train['Sepssis'] == 'Positive']

# Scatter plot with regression line for patients with positive sepsis results
plt.figure(figsize=(10, 6))
scatter_plot = sns.regplot(x='Age', y='PRG', data=sepsis_positive_data, scatter_kws={'alpha': 0.5}, line_kws={'color': 'red'})

# Customizing legend labels
#scatter_plot.legend(title='Legend', loc='upper left')

plt.title('Scatter Plot of Age vs. Plasma Glucose for Sepsis-Positive Patients')
plt.xlabel('Age')
plt.ylabel('Plasma Glucose (PRG)')
plt.show()

# %% [markdown]
# **3. What is the association between blood pressure (PR) and the risk of developing sepsis in ICU patients? Are there specific blood pressure ranges that are more commonly observed in patients who develop sepsis?**

# %%
# Filter data for patients with positive and negative sepsis test results
sepsis_positive_data = train[train['Sepssis'] == 'Positive']
sepsis_negative_data = train[train['Sepssis'] == 'Negative']

#visualizing
plt.figure(figsize=(12, 6))

# Distribution plot for sepsis-positive group
sns.histplot(sepsis_positive_data['PR'], kde=True, color='red', label='Sepsis Positive', alpha=0.7)

# Distribution plot for sepsis-negative group
sns.histplot(sepsis_negative_data['PR'], kde=True, color='blue', label='Sepsis Negative', alpha=0.7)

plt.title('Distribution of Blood Pressure in Sepsis Positive vs. Sepsis Negative Patients')
plt.xlabel('Blood Pressure (PR)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# There is an association of Blood Pressure and  risk of developing Sepsis Disease. High Blood pressure  is associated with Sepsis risks as shown in the chart.

# %% [markdown]
# **4. Does the body mass index (M11) of ICU patients show any significant correlation with specific blood work results, such as plasma glucose (PRG) or blood work result-4 (BD2)?**

# %%
# Scatter plot with regression line for BMI vs. PRG
plt.figure(figsize=(12, 6))
sns.regplot(x='M11', y='PRG', data=train, scatter_kws={'alpha': 0.5}, line_kws={'color': 'blue'})

plt.title('BMI vs. Plasma Glucose (PRG) in ICU Patients')
plt.xlabel('Body Mass Index (M11)')
plt.ylabel('Plasma Glucose (PRG)')
plt.show()

# Scatter plot with regression line for BMI vs. BD2
plt.figure(figsize=(12, 6))
sns.regplot(x='M11', y='BD2', data=train, scatter_kws={'alpha': 0.5}, line_kws={'color': 'green'})

plt.title('BMI vs. Blood Work Result-4 (BD2) in ICU Patients')
plt.xlabel('Body Mass Index (M11)')
plt.ylabel('Blood Work Result-4 (BD2)')
plt.show()

# %%
#Using a heatmap to further investigate the correlation

correlation_data = train[['M11', 'PRG', 'BD2']]
correlation_matrix = correlation_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap: BMI, PRG, BD2 in ICU Patients')
plt.show()

# %% [markdown]
# **There is a Weak Correlation:-** the correlation is close to 0, there may not be a strong linear relationship between BMI and PRG or BD2.

# %% [markdown]
# **5. How does the distribution of patients' age vary across different insurance groups?**

# %%
# Create age groups
train['Age_Group'] = pd.cut(train['Age'], bins=[0, 30, 50, 100], labels=['Young', 'Middle-Aged', 'Old-Age'])

# Count the number of patients in each age group and insurance category
age_insurance_counts = train.groupby(['Age_Group', 'Insurance'],observed=False).size().reset_index(name='Counts')

# Define color palette for insurance categories
insurance_palette = {1: 'blue', 0: 'orange'}

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Age_Group', y='Counts', hue='Insurance', data=age_insurance_counts, palette=insurance_palette)

plt.title('Distribution of Patients\' Age in Different Insurance Groups and Age Categories')
plt.xlabel('Age Group')
plt.ylabel('Number of Patients')
plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %% [markdown]
# **6. How do age, plasma glucose levels (PRG), and blood pressure (PR) collectively contribute to the prediction of sepsis outcomes in ICU patients?**

# %%
# Select relevant columns
columns_of_interest = ['Age', 'PRG', 'PR', 'Sepssis']
df_subset = train[columns_of_interest]

# Create separate dataframes for Negative and Positive outcomes
df_negative = df_subset[df_subset['Sepssis'] == 'Negative']
df_positive = df_subset[df_subset['Sepssis'] == 'Positive']

# Set up the figure and axes for violin plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 10))

# Violin plots for Age
sns.violinplot(x='Sepssis', y='Age', data=df_subset, ax=axes[0], hue='Sepssis', palette='husl', legend=False)
axes[0].set_title('Violin Plot for Age')

# Violin plots for PRG
sns.violinplot(x='Sepssis', y='PRG', data=df_subset, ax=axes[1], hue='Sepssis', palette='husl', legend=False)
axes[1].set_title('Violin Plot for PRG')

# Violin plots for PR
sns.violinplot(x='Sepssis', y='PR', data=df_subset, ax=axes[2], hue='Sepssis', palette='husl', legend=False)
axes[2].set_title('Violin Plot for PR')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **3. Data Preparation**

# %% [markdown]
# ##### **I. Splitting Data to X and y and training and evaluation sets**

# %%
train.head(5)
# Out:
#           ID  PRG   PL  PR  SK   TS   M11    BD2  Age  Insurance   Sepssis  \
# 0  ICU200010    6  148  72  35    0  33.6  0.627   50          0  Positive
# 1  ICU200011    1   85  66  29    0  26.6  0.351   31          0  Negative
# 2  ICU200012    8  183  64   0    0  23.3  0.672   32          1  Positive
# 3  ICU200013    1   89  66  23   94  28.1  0.167   21          1  Negative
# 4  ICU200014    0  137  40  35  168  43.1  2.288   33          1  Positive
#
#      Age_Group
# 0  Middle-Aged
# 1  Middle-Aged
# 2  Middle-Aged
# 3        Young
# 4  Middle-Aged

# %%
# Features (X) and target variable (y)
X = train.drop(['Sepssis', 'ID','Age_Group'], axis=1)  # 'Sepssis' is the target variable and other not needed columns
y = train['Sepssis']

# Split the data into train and test sets (80% train, 20% test)
X_train, X_eval, y_train, y_eval = train_test_split(X, y, train_size=0.8, random_state=42,stratify=y)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_eval shape:", X_eval.shape)
print("y_eval shape:", y_eval.shape)
#X input features
Column_inputs = X.columns
Categorical_columns = y.name
# Out:
# X_train shape: (479, 9)
# y_train shape: (479,)
# X_eval shape: (120, 9)
# y_eval shape: (120,)

# %%
Categorical_columns
# Out:
# 'Sepssis'

# %%
Column_inputs
# Out:
# Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')

# %%
#check if data is balanced
y_train.value_counts()
# Out:
# Sepssis
# Negative    313
# Positive    166
# Name: count, dtype: int64

# %%
# Define SMOTE strategy
smote = SMOTE(sampling_strategy='auto', random_state=42)

#Summarize class distribution before SMOTE
print("Before SMOTE: ", Counter(y_train))

#Apply SMOTE to balance the training set
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Summarize class distribution after SMOTE
print("After SMOTE: ", Counter(y_train_resampled))
# Out:
# Before SMOTE:  Counter({'Negative': 313, 'Positive': 166})
# After SMOTE:  Counter({'Negative': 313, 'Positive': 313})

# %%
#Rechecking class imbalance target variable
y_train_resampled.value_counts()
# Out:
# Sepssis
# Negative    313
# Positive    313
# Name: count, dtype: int64

# %% [markdown]
# ##### **II. Create a pipeline to preprocess the data**

# %%
#Instatiate preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(),Column_inputs),
        ('log transformation', FunctionTransformer(np.log1p),Column_inputs)
    ]
)

#instatiate the pipeline
pipeline = Pipeline(steps=
                    ('preprocessor', preprocessor)
                    #'model', model instance) #Model will change based on the model being trained
)

# %% [markdown]
# **III. Encoding**

# %%
#encoding the target variable for both Train and Evaluation sets
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train_resampled)
y_eval_encoded = encoder.transform(y_eval)

# %% [markdown]
# ### **3. Model Training and Evaluation**

# %% [markdown]
# ##### **I. K-Nearest Neighbour (Distance model)**

# %%
#Instatiating the knn Pipeline
knn_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('knn_model', KNeighborsClassifier())
]) #Model will change based on the model being trained

# %%
#Training
knn_model =knn_pipeline.fit(X_train_resampled, y_train_encoded)

# %%
#Model Evaluation

knn_pred = knn_pipeline.predict(X_eval)

# %%
#Computing the metrics
knn_metrics = classification_report(y_eval_encoded,knn_pred)

print(knn_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.63      0.72        78
#            1       0.52      0.76      0.62        42
#
#     accuracy                           0.68       120
#    macro avg       0.68      0.70      0.67       120
# weighted avg       0.72      0.68      0.68       120

# %%
# Compute confusion matrix
cm = confusion_matrix(y_eval_encoded, knn_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# The accuracy is 0.68, indicating that the model is correct about 68% of the time. Of the 120 classes:
#
# - True Negatives (TN): 49 instances were correctly predicted as class 0 (Negative).
#
# - False Positives (FP): 29 instances were incorrectly predicted as class 1 (Positive) when they were actually class 0.
#
# - False Negatives (FN): 10 instances were incorrectly predicted as class 0 when they were actually class 1.
#
# - True Positives (TP): 32 instances were correctly predicted as class 1.

# %% [markdown]
# **II. Decision Tree (Decision Tree)**

# %%
#Instatiating the dt Pipeline
dt_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('dt_model', DecisionTreeClassifier())
]) #Model will change based on the model being trained

# %%
#Training
dt_model = dt_pipeline.fit(X_train_resampled, y_train_encoded)

# %%
#Model Evaluation

dt_pred = dt_pipeline.predict(X_eval)

# %%
#Computing the metrics
dt_metrics = classification_report(y_eval_encoded,dt_pred)

print(dt_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        78
#            1       0.56      0.67      0.61        42
#
#     accuracy                           0.70       120
#    macro avg       0.68      0.69      0.68       120
# weighted avg       0.72      0.70      0.70       120

# %%
# Compute confusion matrix
cm = confusion_matrix(y_eval_encoded, dt_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# **III.XgB Boost**

# %%
#Instatiating the dt Pipeline
xgb_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('xgb_model', XGBClassifier())
]) #Model will change based on the model being trained

# %%
#Training
xgb_model = xgb_pipeline.fit(X_train_resampled, y_train_encoded)

# %%
#Model Evaluation

xgb_pred = xgb_pipeline.predict(X_eval)

# %%
#Computing the metrics
xgb_metrics = classification_report(y_eval_encoded,xgb_pred)

print(xgb_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74        78
#            1       0.54      0.67      0.60        42
#
#     accuracy                           0.68       120
#    macro avg       0.67      0.68      0.67       120
# weighted avg       0.70      0.68      0.69       120

# %%
# Compute confusion matrix
cm = confusion_matrix(y_eval_encoded, xgb_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# ##### **IV. Random Forest Classifier Model**

# %%
#Instatiating the dt Pipeline
rfc_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('xgb_model', RandomForestClassifier())
]) #Model will change based on the model being trained

# %%
#Training
rfc_model = rfc_pipeline.fit(X_train_resampled, y_train_encoded)

# %%
#Model Evaluation

rfc_pred = rfc_pipeline.predict(X_eval)

# %%
#Computing the metrics
rfc_metrics = classification_report(y_eval_encoded,rfc_pred)

print(rfc_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75        78
#            1       0.55      0.64      0.59        42
#
#     accuracy                           0.69       120
#    macro avg       0.67      0.68      0.67       120
# weighted avg       0.71      0.69      0.70       120

# %%
# Compute confusion matrix
cm = confusion_matrix(y_eval_encoded, rfc_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# ##### **Models Comparison**

# %%
# Using the metrics
print('knn metrics', knn_metrics, 'dt metrics', dt_metrics, 'xgb metrics', xgb_metrics, 'rfc metrics', rfc_metrics)
# Out:
# knn metrics               precision    recall  f1-score   support
#
#            0       0.83      0.63      0.72        78
#            1       0.52      0.76      0.62        42
#
#     accuracy                           0.68       120
#    macro avg       0.68      0.70      0.67       120
# weighted avg       0.72      0.68      0.68       120
#  dt metrics               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        78
#            1       0.56      0.67      0.61        42
#
#     accuracy                           0.70       120
#    macro avg       0.68      0.69      0.68       120
# weighted avg       0.72      0.70      0.70       120
#  xgb metrics               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74        78
#            1       0.54      0.67      0.60        42
#
#     accuracy                           0.68       120
#    macro avg       0.67      0.68      0.67       120
# weighted avg       0.70      0.68      0.69       120
#  rfc metrics               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75        78
#            1       0.55      0.64      0.59        42
#
#     accuracy                           0.69       120
#    macro avg       0.67      0.68      0.67       120
# weighted avg       0.71      0.69      0.70       120

# %% [markdown]
# Our best performing models are Decision Tree and XGB Boost Classifier we going to hperparameter tune to improve the models for and select the best performing to create a Fast API to make accurate predictions

# %% [markdown]
# ##### **Hyperparameter Tuning**
# Here we going to hypertune the XGB boost model and Decision tree.
# We are going to use **GridSearchCV (Cross-Validated Grid Search)** to systematically search through a predefined set of hyperparameter values to find the combination that results in the best model performance according to a specified evaluation metric.

# %%
#displaying the parameters of the models by model variables saved.
print(xgb_model.get_params(),dt_model.get_params())
# Out:
# {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')),
#                                 ('log transformation',
#                                  FunctionTransformer(func=<ufunc 'log1p'>),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))])), ('xgb_model', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...))], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')),
#                                 ('log transformation',
#                                  FunctionTransformer(func=<ufunc 'log1p'>),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))]), 'xgb_model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('scaler', StandardScaler(), Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')), ('log transformation', FunctionTransformer(func=<ufunc 'log1p'>), Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__scaler': StandardScaler(), 'preprocessor__log transformation': FunctionTransformer(func=<ufunc 'log1p'>), 'preprocessor__scaler__copy': True, 'preprocessor__scaler__with_mean': True, 'preprocessor__scaler__with_std': True, 'preprocessor__log transformation__accept_sparse': False, 'preprocessor__log transformation__check_inverse': True, 'preprocessor__log transformation__feature_names_out': None, 'preprocessor__log transformation__func': <ufunc 'log1p'>, 'preprocessor__log transformation__inv_kw_args': None, 'preprocessor__log transformation__inverse_func': None, 'preprocessor__log transformation__kw_args': None, 'preprocessor__log transformation__validate': False, 'xgb_model__objective': 'binary:logistic', 'xgb_model__base_score': None, 'xgb_model__booster': None, 'xgb_model__callbacks': None, 'xgb_model__colsample_bylevel': None, 'xgb_model__colsample_bynode': None, 'xgb_model__colsample_bytree': None, 'xgb_model__device': None, 'xgb_model__early_stopping_rounds': None, 'xgb_model__enable_categorical': False, 'xgb_model__eval_metric': None, 'xgb_model__feature_types': None, 'xgb_model__gamma': None, 'xgb_model__grow_policy': None, 'xgb_model__importance_type': None, 'xgb_model__interaction_constraints': None, 'xgb_model__learning_rate': None, 'xgb_model__max_bin': None, 'xgb_model__max_cat_threshold': None, 'xgb_model__max_cat_to_onehot': None, 'xgb_model__max_delta_step': None, 'xgb_model__max_depth': None, 'xgb_model__max_leaves': None, 'xgb_model__min_child_weight': None, 'xgb_model__missing': nan, 'xgb_model__monotone_constraints': None, 'xgb_model__multi_strategy': None, 'xgb_model__n_estimators': None, 'xgb_model__n_jobs': None, 'xgb_model__num_parallel_tree': None, 'xgb_model__random_state': None, 'xgb_model__reg_alpha': None, 'xgb_model__reg_lambda': None, 'xgb_model__sampling_method': None, 'xgb_model__scale_pos_weight': None, 'xgb_model__subsample': None, 'xgb_model__tree_method': None, 'xgb_model__validate_parameters': None, 'xgb_model__verbosity': None} {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')),
#                                 ('log transformation',
#                                  FunctionTransformer(func=<ufunc 'log1p'>),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))])), ('dt_model', DecisionTreeClassifier())], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')),
#                                 ('log transformation',
#                                  FunctionTransformer(func=<ufunc 'log1p'>),
#                                  Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))]), 'dt_model': DecisionTreeClassifier(), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('scaler', StandardScaler(), Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')), ('log transformation', FunctionTransformer(func=<ufunc 'log1p'>), Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__scaler': StandardScaler(), 'preprocessor__log transformation': FunctionTransformer(func=<ufunc 'log1p'>), 'preprocessor__scaler__copy': True, 'preprocessor__scaler__with_mean': True, 'preprocessor__scaler__with_std': True, 'preprocessor__log transformation__accept_sparse': False, 'preprocessor__log transformation__check_inverse': True, 'preprocessor__log transformation__feature_names_out': None, 'preprocessor__log transformation__func': <ufunc 'log1p'>, 'preprocessor__log transformation__inv_kw_args': None, 'preprocessor__log transformation__inverse_func': None, 'preprocessor__log transformation__kw_args': None, 'preprocessor__log transformation__validate': False, 'dt_model__ccp_alpha': 0.0, 'dt_model__class_weight': None, 'dt_model__criterion': 'gini', 'dt_model__max_depth': None, 'dt_model__max_features': None, 'dt_model__max_leaf_nodes': None, 'dt_model__min_impurity_decrease': 0.0, 'dt_model__min_samples_leaf': 1, 'dt_model__min_samples_split': 2, 'dt_model__min_weight_fraction_leaf': 0.0, 'dt_model__random_state': None, 'dt_model__splitter': 'best'}

# %%
# Define hyperparameter search space for Decision Tree
dt_param_grid = {
    'dt_model__max_depth': [None, 5, 10, 15],
    'dt_model__min_samples_split': [2, 5, 10],
    'dt_model__min_samples_leaf': [1, 2, 4],
}

# Define hyperparameter search space for XGBoost
xgb_param_grid = {
    'xgb_model__n_estimators': [50, 100, 200],
    'xgb_model__learning_rate': [0.01, 0.1, 0.2],
    'xgb_model__max_depth': [3, 5, 7],
}

# %%
# Create GridSearchCV instance for dt_model
searcher_dt = GridSearchCV(dt_model,
                        param_grid = dt_param_grid,
                        scoring = ['accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall'],
                        refit = 'balanced_accuracy',
                        cv= 5,
                        verbose = 3)




# Create GridSearchCV instance xgb
searcher_xgb = GridSearchCV(xgb_model,
                        param_grid = xgb_param_grid,
                        scoring = ['accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall'],
                        refit = 'balanced_accuracy',
                        cv= 5,
                        verbose = 3)

# %%
X_train_resampled.dtypes
# Out:
# PRG            int64
# PL             int64
# PR             int64
# SK             int64
# TS             int64
# M11          float64
# BD2          float64
# Age            int64
# Insurance      int64
# dtype: object

# %%
#fitting the train data with the gridsearchCV
searcher_dt.fit(X_train_resampled, y_train_encoded)
searcher_xgb.fit(X_train_resampled, y_train_encoded)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.750) precision: (test=0.738) recall: (test=0.762) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.648) balanced_accuracy: (test=0.648) f1: (test=0.639) precision: (test=0.650) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.740) precision: (test=0.723) recall: (test=0.758) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.864) balanced_accuracy: (test=0.864) f1: (test=0.870) precision: (test=0.838) recall: (test=0.905) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.762) balanced_accuracy: (test=0.762) f1: (test=0.762) precision: (test=0.762) recall: (test=0.762) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.632) balanced_accuracy: (test=0.632) f1: (test=0.629) precision: (test=0.629) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.728) balanced_accuracy: (test=0.727) f1: (test=0.707) precision: (test=0.759) recall: (test=0.661) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.840) precision: (test=0.809) recall: (test=0.873) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.790) precision: (test=0.803) recall: (test=0.778) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.722) balanced_accuracy: (test=0.722) f1: (test=0.720) precision: (test=0.726) recall: (test=0.714) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.664) balanced_accuracy: (test=0.664) f1: (test=0.661) precision: (test=0.661) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.728) balanced_accuracy: (test=0.727) f1: (test=0.707) precision: (test=0.759) recall: (test=0.661) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.831) precision: (test=0.806) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.827) precision: (test=0.786) recall: (test=0.873) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.738) precision: (test=0.763) recall: (test=0.714) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.672) balanced_accuracy: (test=0.672) f1: (test=0.677) precision: (test=0.662) recall: (test=0.694) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.704) balanced_accuracy: (test=0.703) f1: (test=0.673) precision: (test=0.745) recall: (test=0.613) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.784) precision: (test=0.790) recall: (test=0.778) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.806) precision: (test=0.788) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.721) precision: (test=0.746) recall: (test=0.698) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.656) balanced_accuracy: (test=0.656) f1: (test=0.645) precision: (test=0.661) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.720) balanced_accuracy: (test=0.719) f1: (test=0.696) precision: (test=0.755) recall: (test=0.645) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.790) precision: (test=0.803) recall: (test=0.778) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.828) precision: (test=0.815) recall: (test=0.841) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.706) balanced_accuracy: (test=0.706) f1: (test=0.699) precision: (test=0.717) recall: (test=0.683) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.648) balanced_accuracy: (test=0.648) f1: (test=0.627) precision: (test=0.661) recall: (test=0.597) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.733) precision: (test=0.759) recall: (test=0.710) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.728) balanced_accuracy: (test=0.728) f1: (test=0.712) precision: (test=0.764) recall: (test=0.667) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.812) precision: (test=0.800) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.738) balanced_accuracy: (test=0.738) f1: (test=0.736) precision: (test=0.742) recall: (test=0.730) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.704) balanced_accuracy: (test=0.704) f1: (test=0.689) precision: (test=0.719) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.720) balanced_accuracy: (test=0.719) f1: (test=0.696) precision: (test=0.755) recall: (test=0.645) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.780) precision: (test=0.800) recall: (test=0.762) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.781) precision: (test=0.769) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.738) balanced_accuracy: (test=0.738) f1: (test=0.736) precision: (test=0.742) recall: (test=0.730) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.688) balanced_accuracy: (test=0.688) f1: (test=0.678) precision: (test=0.695) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.744) balanced_accuracy: (test=0.743) f1: (test=0.714) precision: (test=0.800) recall: (test=0.645) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.784) precision: (test=0.790) recall: (test=0.778) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.825) precision: (test=0.825) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.750) precision: (test=0.738) recall: (test=0.762) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.696) balanced_accuracy: (test=0.696) f1: (test=0.678) precision: (test=0.714) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.727) precision: (test=0.746) recall: (test=0.710) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.768) precision: (test=0.774) recall: (test=0.762) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=None, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.806) precision: (test=0.820) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.768) precision: (test=0.707) recall: (test=0.841) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.632) balanced_accuracy: (test=0.632) f1: (test=0.646) precision: (test=0.618) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.772) precision: (test=0.754) recall: (test=0.790) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.856) balanced_accuracy: (test=0.856) f1: (test=0.862) precision: (test=0.836) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.794) precision: (test=0.794) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.768) precision: (test=0.707) recall: (test=0.841) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.640) balanced_accuracy: (test=0.640) f1: (test=0.651) precision: (test=0.627) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.768) precision: (test=0.762) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.856) balanced_accuracy: (test=0.856) f1: (test=0.862) precision: (test=0.836) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.778) precision: (test=0.778) recall: (test=0.778) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.754) balanced_accuracy: (test=0.754) f1: (test=0.774) precision: (test=0.716) recall: (test=0.841) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.616) balanced_accuracy: (test=0.616) f1: (test=0.625) precision: (test=0.606) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.750) precision: (test=0.727) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.856) balanced_accuracy: (test=0.856) f1: (test=0.862) precision: (test=0.836) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.778) precision: (test=0.778) recall: (test=0.778) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.750) precision: (test=0.699) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.640) balanced_accuracy: (test=0.640) f1: (test=0.651) precision: (test=0.627) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.768) precision: (test=0.762) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.844) precision: (test=0.831) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.794) precision: (test=0.794) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.750) precision: (test=0.699) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.640) balanced_accuracy: (test=0.640) f1: (test=0.651) precision: (test=0.627) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.768) precision: (test=0.762) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.844) precision: (test=0.831) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.794) precision: (test=0.794) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.765) precision: (test=0.712) recall: (test=0.825) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.656) balanced_accuracy: (test=0.656) f1: (test=0.672) precision: (test=0.638) recall: (test=0.710) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.750) precision: (test=0.727) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.835) precision: (test=0.828) recall: (test=0.841) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.794) precision: (test=0.794) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.722) balanced_accuracy: (test=0.722) f1: (test=0.745) precision: (test=0.689) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.624) balanced_accuracy: (test=0.624) f1: (test=0.641) precision: (test=0.609) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.760) balanced_accuracy: (test=0.760) f1: (test=0.762) precision: (test=0.750) recall: (test=0.774) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.844) precision: (test=0.831) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.722) balanced_accuracy: (test=0.722) f1: (test=0.745) precision: (test=0.689) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.616) balanced_accuracy: (test=0.616) f1: (test=0.631) precision: (test=0.603) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.778) precision: (test=0.766) recall: (test=0.790) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.837) precision: (test=0.818) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.722) balanced_accuracy: (test=0.722) f1: (test=0.745) precision: (test=0.689) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.632) balanced_accuracy: (test=0.632) f1: (test=0.641) precision: (test=0.621) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.760) balanced_accuracy: (test=0.760) f1: (test=0.766) precision: (test=0.742) recall: (test=0.790) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.848) balanced_accuracy: (test=0.848) f1: (test=0.855) precision: (test=0.824) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=5, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.762) balanced_accuracy: (test=0.762) f1: (test=0.769) precision: (test=0.746) recall: (test=0.794) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.656) balanced_accuracy: (test=0.656) f1: (test=0.650) precision: (test=0.656) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.738) precision: (test=0.750) recall: (test=0.726) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.842) precision: (test=0.800) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.806) precision: (test=0.788) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.762) balanced_accuracy: (test=0.762) f1: (test=0.773) precision: (test=0.739) recall: (test=0.810) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.656) balanced_accuracy: (test=0.656) f1: (test=0.667) precision: (test=0.642) recall: (test=0.694) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.733) precision: (test=0.759) recall: (test=0.710) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.848) precision: (test=0.812) recall: (test=0.889) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.840) precision: (test=0.809) recall: (test=0.873) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.730) precision: (test=0.730) recall: (test=0.730) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.656) balanced_accuracy: (test=0.656) f1: (test=0.639) precision: (test=0.667) recall: (test=0.613) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.723) precision: (test=0.754) recall: (test=0.694) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.844) precision: (test=0.831) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.827) precision: (test=0.786) recall: (test=0.873) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.738) balanced_accuracy: (test=0.738) f1: (test=0.732) precision: (test=0.750) recall: (test=0.714) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.688) balanced_accuracy: (test=0.688) f1: (test=0.672) precision: (test=0.702) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.712) balanced_accuracy: (test=0.711) f1: (test=0.690) precision: (test=0.741) recall: (test=0.645) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.780) precision: (test=0.800) recall: (test=0.762) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.833) precision: (test=0.797) recall: (test=0.873) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.706) balanced_accuracy: (test=0.706) f1: (test=0.694) precision: (test=0.724) recall: (test=0.667) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.672) balanced_accuracy: (test=0.672) f1: (test=0.667) precision: (test=0.672) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.704) balanced_accuracy: (test=0.703) f1: (test=0.678) precision: (test=0.736) recall: (test=0.629) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.803) precision: (test=0.831) recall: (test=0.778) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.840) balanced_accuracy: (test=0.840) f1: (test=0.846) precision: (test=0.821) recall: (test=0.873) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.698) balanced_accuracy: (test=0.698) f1: (test=0.689) precision: (test=0.712) recall: (test=0.667) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.632) balanced_accuracy: (test=0.632) f1: (test=0.610) precision: (test=0.643) recall: (test=0.581) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.728) balanced_accuracy: (test=0.728) f1: (test=0.717) precision: (test=0.741) recall: (test=0.694) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.723) precision: (test=0.768) recall: (test=0.683) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.822) precision: (test=0.803) recall: (test=0.841) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.746) precision: (test=0.746) recall: (test=0.746) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.696) balanced_accuracy: (test=0.696) f1: (test=0.689) precision: (test=0.700) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.767) precision: (test=0.793) recall: (test=0.742) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.760) precision: (test=0.793) recall: (test=0.730) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.791) precision: (test=0.773) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.738) balanced_accuracy: (test=0.738) f1: (test=0.736) precision: (test=0.742) recall: (test=0.730) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.704) balanced_accuracy: (test=0.704) f1: (test=0.694) precision: (test=0.712) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.718) precision: (test=0.764) recall: (test=0.677) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.760) balanced_accuracy: (test=0.760) f1: (test=0.754) precision: (test=0.780) recall: (test=0.730) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.815) precision: (test=0.791) recall: (test=0.841) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.750) precision: (test=0.738) recall: (test=0.762) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.680) balanced_accuracy: (test=0.680) f1: (test=0.667) precision: (test=0.690) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.752) balanced_accuracy: (test=0.752) f1: (test=0.748) precision: (test=0.754) recall: (test=0.742) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=10, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.803) precision: (test=0.797) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.754) precision: (test=0.731) recall: (test=0.778) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.648) balanced_accuracy: (test=0.648) f1: (test=0.639) precision: (test=0.650) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.736) precision: (test=0.730) recall: (test=0.742) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.831) precision: (test=0.806) recall: (test=0.857) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=2; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.819) precision: (test=0.812) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.754) balanced_accuracy: (test=0.754) f1: (test=0.752) precision: (test=0.758) recall: (test=0.746) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.640) balanced_accuracy: (test=0.640) f1: (test=0.634) precision: (test=0.639) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.718) precision: (test=0.764) recall: (test=0.677) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.840) precision: (test=0.809) recall: (test=0.873) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=5; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.818) precision: (test=0.783) recall: (test=0.857) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.714) balanced_accuracy: (test=0.714) f1: (test=0.700) precision: (test=0.737) recall: (test=0.667) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.624) balanced_accuracy: (test=0.624) f1: (test=0.598) precision: (test=0.636) recall: (test=0.565) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.718) precision: (test=0.764) recall: (test=0.677) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.822) precision: (test=0.803) recall: (test=0.841) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=1, dt_model__min_samples_split=10; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.815) precision: (test=0.791) recall: (test=0.841) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.714) balanced_accuracy: (test=0.714) f1: (test=0.700) precision: (test=0.737) recall: (test=0.667) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.624) balanced_accuracy: (test=0.624) f1: (test=0.618) precision: (test=0.623) recall: (test=0.613) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.704) balanced_accuracy: (test=0.703) f1: (test=0.678) precision: (test=0.736) recall: (test=0.629) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.777) precision: (test=0.810) recall: (test=0.746) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=2; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.819) precision: (test=0.812) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.706) balanced_accuracy: (test=0.706) f1: (test=0.704) precision: (test=0.710) recall: (test=0.698) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.712) balanced_accuracy: (test=0.712) f1: (test=0.700) precision: (test=0.724) recall: (test=0.677) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.720) balanced_accuracy: (test=0.719) f1: (test=0.696) precision: (test=0.755) recall: (test=0.645) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.803) precision: (test=0.797) recall: (test=0.810) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=5; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.800) precision: (test=0.776) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.706) balanced_accuracy: (test=0.706) f1: (test=0.699) precision: (test=0.717) recall: (test=0.683) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.648) balanced_accuracy: (test=0.648) f1: (test=0.633) precision: (test=0.655) recall: (test=0.613) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.733) precision: (test=0.759) recall: (test=0.710) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.723) precision: (test=0.768) recall: (test=0.683) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=2, dt_model__min_samples_split=10; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.815) precision: (test=0.791) recall: (test=0.841) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.746) precision: (test=0.746) recall: (test=0.746) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.688) balanced_accuracy: (test=0.688) f1: (test=0.672) precision: (test=0.702) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.728) balanced_accuracy: (test=0.728) f1: (test=0.712) precision: (test=0.750) recall: (test=0.677) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.760) balanced_accuracy: (test=0.760) f1: (test=0.754) precision: (test=0.780) recall: (test=0.730) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=2; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.781) precision: (test=0.769) recall: (test=0.794) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.746) precision: (test=0.746) recall: (test=0.746) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.680) balanced_accuracy: (test=0.680) f1: (test=0.661) precision: (test=0.696) recall: (test=0.629) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.729) precision: (test=0.768) recall: (test=0.694) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.784) balanced_accuracy: (test=0.784) f1: (test=0.780) precision: (test=0.800) recall: (test=0.762) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=5; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.825) precision: (test=0.825) recall: (test=0.825) total time=   0.0s
# [CV 1/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.750) precision: (test=0.738) recall: (test=0.762) total time=   0.0s
# [CV 2/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.704) balanced_accuracy: (test=0.704) f1: (test=0.684) precision: (test=0.727) recall: (test=0.645) total time=   0.0s
# [CV 3/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.736) balanced_accuracy: (test=0.736) f1: (test=0.727) precision: (test=0.746) recall: (test=0.710) total time=   0.0s
# [CV 4/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.792) balanced_accuracy: (test=0.792) f1: (test=0.797) precision: (test=0.785) recall: (test=0.810) total time=   0.0s
# [CV 5/5] END dt_model__max_depth=15, dt_model__min_samples_leaf=4, dt_model__min_samples_split=10; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.806) precision: (test=0.820) recall: (test=0.794) total time=   0.0s
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.758) precision: (test=0.725) recall: (test=0.794) total time=   0.0s
# [CV 2/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.754) precision: (test=0.721) recall: (test=0.790) total time=   0.0s
# [CV 3/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.767) precision: (test=0.793) recall: (test=0.742) total time=   0.0s
# [CV 4/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.856) balanced_accuracy: (test=0.856) f1: (test=0.864) precision: (test=0.826) recall: (test=0.905) total time=   0.0s
# [CV 5/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.768) balanced_accuracy: (test=0.769) f1: (test=0.748) precision: (test=0.827) recall: (test=0.683) total time=   0.0s
# [CV 1/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.746) precision: (test=0.704) recall: (test=0.794) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.754) precision: (test=0.721) recall: (test=0.790) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.768) balanced_accuracy: (test=0.768) f1: (test=0.772) precision: (test=0.754) recall: (test=0.790) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.864) balanced_accuracy: (test=0.864) f1: (test=0.872) precision: (test=0.829) recall: (test=0.921) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.816) precision: (test=0.823) recall: (test=0.810) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.754) balanced_accuracy: (test=0.754) f1: (test=0.760) precision: (test=0.742) recall: (test=0.778) total time=   0.2s
# [CV 2/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.744) balanced_accuracy: (test=0.744) f1: (test=0.754) precision: (test=0.721) recall: (test=0.790) total time=   0.2s
# [CV 3/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.781) precision: (test=0.758) recall: (test=0.806) total time=   0.2s
# [CV 4/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.872) balanced_accuracy: (test=0.872) f1: (test=0.879) precision: (test=0.841) recall: (test=0.921) total time=   0.2s
# [CV 5/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.880) balanced_accuracy: (test=0.880) f1: (test=0.887) precision: (test=0.843) recall: (test=0.937) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.730) balanced_accuracy: (test=0.730) f1: (test=0.738) precision: (test=0.716) recall: (test=0.762) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.696) balanced_accuracy: (test=0.696) f1: (test=0.703) precision: (test=0.682) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.752) balanced_accuracy: (test=0.752) f1: (test=0.760) precision: (test=0.731) recall: (test=0.790) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.835) precision: (test=0.828) recall: (test=0.841) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.803) precision: (test=0.797) recall: (test=0.810) total time=   0.0s
# [CV 1/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.746) balanced_accuracy: (test=0.746) f1: (test=0.754) precision: (test=0.731) recall: (test=0.778) total time=   0.2s
# [CV 2/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.720) balanced_accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.714) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.776) balanced_accuracy: (test=0.776) f1: (test=0.781) precision: (test=0.758) recall: (test=0.806) total time=   0.2s
# [CV 4/5] END xgb_model__learning_rate=0.01, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.872) balanced_accuracy: (test=0.872) f1: (test=0.879) precision: (test=0.841) recall: (test=0.921) total time=   0.2s
# ...
# [CV 5/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.3s
# [CV 1/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.786) balanced_accuracy: (test=0.786) f1: (test=0.784) precision: (test=0.790) recall: (test=0.778) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.720) balanced_accuracy: (test=0.720) f1: (test=0.729) precision: (test=0.701) recall: (test=0.758) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.803) precision: (test=0.817) recall: (test=0.790) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.896) balanced_accuracy: (test=0.895) f1: (test=0.905) precision: (test=0.838) recall: (test=0.984) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.863) precision: (test=0.789) recall: (test=0.952) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.810) balanced_accuracy: (test=0.810) f1: (test=0.806) precision: (test=0.820) recall: (test=0.794) total time=   0.2s
# [CV 2/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.720) balanced_accuracy: (test=0.720) f1: (test=0.729) precision: (test=0.701) recall: (test=0.758) total time=   0.2s
# [CV 3/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.813) precision: (test=0.820) recall: (test=0.806) total time=   0.2s
# [CV 4/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.896) balanced_accuracy: (test=0.895) f1: (test=0.905) precision: (test=0.838) recall: (test=0.984) total time=   0.2s
# [CV 5/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.2s
# [CV 1/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.794) balanced_accuracy: (test=0.794) f1: (test=0.787) precision: (test=0.814) recall: (test=0.762) total time=   0.3s
# [CV 2/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.728) balanced_accuracy: (test=0.728) f1: (test=0.738) precision: (test=0.706) recall: (test=0.774) total time=   0.3s
# [CV 3/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.816) precision: (test=0.810) recall: (test=0.823) total time=   0.3s
# [CV 4/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.864) balanced_accuracy: (test=0.863) f1: (test=0.876) precision: (test=0.811) recall: (test=0.952) total time=   0.3s
# [CV 5/5] END xgb_model__learning_rate=0.1, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.3s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.794) balanced_accuracy: (test=0.794) f1: (test=0.790) precision: (test=0.803) recall: (test=0.778) total time=   0.0s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.688) balanced_accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.683) recall: (test=0.694) total time=   0.0s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.810) precision: (test=0.797) recall: (test=0.823) total time=   0.0s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.888) balanced_accuracy: (test=0.887) f1: (test=0.896) precision: (test=0.845) recall: (test=0.952) total time=   0.0s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=50; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.0s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.817) balanced_accuracy: (test=0.817) f1: (test=0.822) precision: (test=0.803) recall: (test=0.841) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.680) balanced_accuracy: (test=0.680) f1: (test=0.683) precision: (test=0.672) recall: (test=0.694) total time=   0.0s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.797) precision: (test=0.803) recall: (test=0.790) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.888) balanced_accuracy: (test=0.887) f1: (test=0.899) precision: (test=0.827) recall: (test=0.984) total time=   0.0s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=100; accuracy: (test=0.840) balanced_accuracy: (test=0.839) f1: (test=0.851) precision: (test=0.803) recall: (test=0.905) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.802) balanced_accuracy: (test=0.802) f1: (test=0.800) precision: (test=0.806) recall: (test=0.794) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.704) balanced_accuracy: (test=0.704) f1: (test=0.704) precision: (test=0.698) recall: (test=0.710) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.832) balanced_accuracy: (test=0.832) f1: (test=0.835) precision: (test=0.815) recall: (test=0.855) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.872) balanced_accuracy: (test=0.871) f1: (test=0.884) precision: (test=0.813) recall: (test=0.968) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=3, xgb_model__n_estimators=200; accuracy: (test=0.864) balanced_accuracy: (test=0.863) f1: (test=0.876) precision: (test=0.811) recall: (test=0.952) total time=   0.2s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.825) balanced_accuracy: (test=0.825) f1: (test=0.825) precision: (test=0.825) recall: (test=0.825) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.728) balanced_accuracy: (test=0.728) f1: (test=0.734) precision: (test=0.712) recall: (test=0.758) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.816) balanced_accuracy: (test=0.816) f1: (test=0.816) precision: (test=0.810) recall: (test=0.823) total time=   0.0s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.880) balanced_accuracy: (test=0.879) f1: (test=0.892) precision: (test=0.816) recall: (test=0.984) total time=   0.0s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=50; accuracy: (test=0.832) balanced_accuracy: (test=0.831) f1: (test=0.849) precision: (test=0.776) recall: (test=0.937) total time=   0.0s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.802) balanced_accuracy: (test=0.802) f1: (test=0.800) precision: (test=0.806) recall: (test=0.794) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.680) balanced_accuracy: (test=0.680) f1: (test=0.692) precision: (test=0.662) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.824) balanced_accuracy: (test=0.824) f1: (test=0.823) precision: (test=0.823) recall: (test=0.823) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.872) balanced_accuracy: (test=0.871) f1: (test=0.886) precision: (test=0.805) recall: (test=0.984) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=100; accuracy: (test=0.856) balanced_accuracy: (test=0.855) f1: (test=0.868) precision: (test=0.808) recall: (test=0.937) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.794) balanced_accuracy: (test=0.794) f1: (test=0.787) precision: (test=0.814) recall: (test=0.762) total time=   0.2s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.704) balanced_accuracy: (test=0.704) f1: (test=0.709) precision: (test=0.692) recall: (test=0.726) total time=   0.2s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.800) precision: (test=0.794) recall: (test=0.806) total time=   0.2s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.856) balanced_accuracy: (test=0.855) f1: (test=0.871) precision: (test=0.792) recall: (test=0.968) total time=   0.2s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=5, xgb_model__n_estimators=200; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.2s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.802) balanced_accuracy: (test=0.802) f1: (test=0.797) precision: (test=0.817) recall: (test=0.778) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.696) balanced_accuracy: (test=0.696) f1: (test=0.703) precision: (test=0.682) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.803) precision: (test=0.817) recall: (test=0.790) total time=   0.1s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.856) balanced_accuracy: (test=0.855) f1: (test=0.868) precision: (test=0.808) recall: (test=0.937) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=50; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.794) balanced_accuracy: (test=0.794) f1: (test=0.790) precision: (test=0.803) recall: (test=0.778) total time=   0.1s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.720) balanced_accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.714) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.808) balanced_accuracy: (test=0.808) f1: (test=0.806) precision: (test=0.806) recall: (test=0.806) total time=   0.2s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.872) balanced_accuracy: (test=0.871) f1: (test=0.881) precision: (test=0.831) recall: (test=0.937) total time=   0.1s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=100; accuracy: (test=0.856) balanced_accuracy: (test=0.855) f1: (test=0.868) precision: (test=0.808) recall: (test=0.937) total time=   0.1s
# [CV 1/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.770) balanced_accuracy: (test=0.770) f1: (test=0.764) precision: (test=0.783) recall: (test=0.746) total time=   0.3s
# [CV 2/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.680) balanced_accuracy: (test=0.680) f1: (test=0.677) precision: (test=0.677) recall: (test=0.677) total time=   0.2s
# [CV 3/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.800) balanced_accuracy: (test=0.800) f1: (test=0.797) precision: (test=0.803) recall: (test=0.790) total time=   0.3s
# [CV 4/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.872) balanced_accuracy: (test=0.871) f1: (test=0.881) precision: (test=0.831) recall: (test=0.937) total time=   0.3s
# [CV 5/5] END xgb_model__learning_rate=0.2, xgb_model__max_depth=7, xgb_model__n_estimators=200; accuracy: (test=0.848) balanced_accuracy: (test=0.847) f1: (test=0.861) precision: (test=0.797) recall: (test=0.937) total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('scaler',
#                                                                          StandardScaler(),
#                                                                          Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object')),
#                                                                         ('log '
#                                                                          'transformation',
#                                                                          FunctionTransformer(func=<ufunc 'log1p'>),
#                                                                          Index(['PRG', 'PL', 'PR', 'SK', 'TS', 'M11', 'BD2', 'Age', 'Insurance'], dtype='object'))])),
#                                        ('...
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None,
#                                                       random_state=None, ...))]),
#              param_grid={'xgb_model__learning_rate': [0.01, 0.1, 0.2],
#                          'xgb_model__max_depth': [3, 5, 7],
#                          'xgb_model__n_estimators': [50, 100, 200]},
#              refit='balanced_accuracy',
#              scoring=['accuracy', 'balanced_accuracy', 'f1', 'precision',
#                       'recall'],
#              verbose=3)

# %%
#the best parameters combination for dt
searcher_dt.best_params_
#the best parameters combination for xgb
searcher_xgb.best_params_
# Out:
# {'xgb_model__learning_rate': 0.1,
#  'xgb_model__max_depth': 5,
#  'xgb_model__n_estimators': 50}

# %%
#Rename the best estimator per model intials
best_dt = searcher_dt.best_estimator_
best_xgb = searcher_xgb.best_estimator_

# %%
#getting the scores

dt_score = searcher_dt.best_score_
xgb_score = searcher_xgb.best_score_
print("Best Decision Tree Classifier Score is:", dt_score)
print("Best XGB Boost Classifier Score is:", xgb_score)
# Out:
# Best Decision Tree Classifier Score is: 0.7666410650281619
# Best XGB Boost Classifier Score is: 0.8208909370199693

# %% [markdown]
# ### **PERSISITING THE  BEST MODEL**

# %%
# Export the model to a .joblib file
joblib.dump(best_xgb, 'xgbmodel.joblib')
# Export the encoder to a .joblib file
joblib.dump(encoder, 'encoder.joblib')
# Out:
# ['encoder.joblib']
